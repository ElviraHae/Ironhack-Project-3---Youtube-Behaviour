# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

# %%
url = 'https://en.wikipedia.org/wiki/List_of_mass_shootings_in_the_United_States'

# %%
html = requests.get(url).content

# %%
soup = BeautifulSoup(html, 'lxml')
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of mass shootings in the United States - Wikipedia</title>
# ...

# %% [markdown]
# ### 2017

# %%
table = soup.find_all('table', attrs = {'class':'wikitable sortable'})[3] ### if you want 2018, you have to change for 2

# %%
table
# Out:
# <table class="wikitable sortable">
# <tbody><tr>
# <th scope="col" style="width: 56px;">Date
# </th>
# <th scope="col" style="width: 84px;">Location
# </th>
# <th data-sort-type="number">Dead
# </th>
# <th data-sort-type="number">Injured
# </th>
# <th data-sort-type="number">Total
# </th>
# <th class="unsortable">Description
# </th></tr>
# <tr>
# <td><span data-sort-value="000000002017-12-31-0000" style="white-space:nowrap">December 31, 2017</span>
# </td>
# <td><a href="/wiki/Highlands_Ranch,_Colorado" title="Highlands Ranch, Colorado">Highlands Ranch, Colorado</a>
# </td>
# <td>2<sup class="reference" id="cite_ref-:0_9-23"><a href="#cite_note-:0-9">[n 1]</a></sup>
# </td>
# <td>6
# </td>
# <td><b>8</b>
# </td>
# ...

# %%
rows = table.find_all('tr')
rows
# Out:
# [<tr>
#  <th scope="col" style="width: 56px;">Date
#  </th>
#  <th scope="col" style="width: 84px;">Location
#  </th>
#  <th data-sort-type="number">Dead
#  </th>
#  <th data-sort-type="number">Injured
#  </th>
#  <th data-sort-type="number">Total
#  </th>
#  <th class="unsortable">Description
#  </th></tr>, <tr>
#  <td><span data-sort-value="000000002017-12-31-0000" style="white-space:nowrap">December 31, 2017</span>
#  </td>
#  <td><a href="/wiki/Highlands_Ranch,_Colorado" title="Highlands Ranch, Colorado">Highlands Ranch, Colorado</a>
#  </td>
#  <td>2<sup class="reference" id="cite_ref-:0_9-23"><a href="#cite_note-:0-9">[n 1]</a></sup>
#  </td>
#  <td>6
#  </td>
#  <td><b>8</b>
#  </td>
# ...

# %%
rows[1].text#.replace(n1)
rows[3].text
# Out:
# '\nNovember 13, 2017\n\nTehama County, California\n\n6[n 1]\n\n12\n\n18\n\nRancho Tehama Reserve shootings: A man killed his wife and hid her body under the floorboards of their home before killing two neighbors, firing at random at people, and then ramming his truck through the gates of an elementary school and firing at those inside. He then drove away and targeted other random victims before being rammed by police and shooting himself. He killed five people and injured twelve others (some with bullet wounds, others were injured by flying glass) before committing suicide.[41]\n'

# %%
rows = [row.text.split('\n') for row in rows[1:]]

# %%
rows[0][1]
rows[0][5]
# Out:
# '2[n 1]'

# %%
dates = [x[1] for x in rows]
dates
# Out:
# ['December 31, 2017',
#  'December 7, 2017',
#  'November 13, 2017',
#  'November 5, 2017',
#  'October 1, 2017',
#  'September 24, 2017',
#  'September 10, 2017',
#  'August 28, 2017',
#  'July 1, 2017',
#  'June 30, 2017',
#  'June 14, 2017',
#  'June 14, 2017',
#  'June 8, 2017',
#  'June 6, 2017',
#  'June 5, 2017',
#  'May 27, 2017',
#  'May 12, 2017',
#  'April 13',
#  'April 10, 2017',
#  'March 26, 2017',
#  'March 22, 2017',
#  'January 6, 2017']

# %%
deaths = [x[5].replace(r'[n 1]',"").replace(r'[n 5]',"") for x in rows]
deaths
# Out:
# ['2',
#  '3',
#  '6',
#  '27',
#  '59',
#  '1',
#  '9',
#  '2',
#  '0',
#  '2',
#  '4',
#  '1',
#  '4',
#  '3',
#  '6',
#  '8',
#  '4',
#  'Fresno, California',
#  '3',
#  '2',
#  '5',
#  '5']

# %%
list_2017 = list(zip(dates,deaths))
list_2017
# Out:
# [('December 31, 2017', '2'),
#  ('December 7, 2017', '3'),
#  ('November 13, 2017', '6'),
#  ('November 5, 2017', '27'),
#  ('October 1, 2017', '59'),
#  ('September 24, 2017', '1'),
#  ('September 10, 2017', '9'),
#  ('August 28, 2017', '2'),
#  ('July 1, 2017', '0'),
#  ('June 30, 2017', '2'),
#  ('June 14, 2017', '4'),
#  ('June 14, 2017', '1'),
#  ('June 8, 2017', '4'),
#  ('June 6, 2017', '3'),
#  ('June 5, 2017', '6'),
#  ('May 27, 2017', '8'),
#  ('May 12, 2017', '4'),
#  ('April 13', 'Fresno, California'),
#  ('April 10, 2017', '3'),
#  ('March 26, 2017', '2'),
#  ('March 22, 2017', '5'),
#  ('January 6, 2017', '5')]
